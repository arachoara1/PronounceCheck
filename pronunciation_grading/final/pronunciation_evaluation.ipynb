# %%
import os
import re
import json
import numpy as np
import librosa
import parselmouth
from scipy.spatial.distance import cosine
from google.cloud import speech
from dotenv import load_dotenv


# Google Cloud Speech-to-Text API 설정
load_dotenv()
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = os.getenv("KEY_PATH")

speech_client = speech.SpeechClient()

# %%
def preprocess_audio(input_path, target_sr=16000):
    """오디오를 읽고 샘플링 속도를 변환"""
    y, sr = librosa.load(input_path, sr=None)
    if sr != target_sr:
        y = librosa.resample(y, orig_sr=sr, target_sr=target_sr)
    return y, target_sr


def recognize_speech(y, sr, language_code="en-US"):
    """Google Speech-to-Text API를 사용해 단어별 타임스탬프 추출"""
    import soundfile as sf
    from io import BytesIO

    buffer = BytesIO()
    sf.write(buffer, y, sr, format="WAV")
    buffer.seek(0)
    audio = speech.RecognitionAudio(content=buffer.read())
    config = speech.RecognitionConfig(
        encoding=speech.RecognitionConfig.AudioEncoding.LINEAR16,
        sample_rate_hertz=sr,
        language_code=language_code,
        enable_word_time_offsets=True,
    )
    response = speech_client.recognize(config=config, audio=audio)

    word_timestamps = []
    for result in response.results:
        for word_info in result.alternatives[0].words:
            word_timestamps.append(
                {
                    "word": word_info.word,
                    "start_time": word_info.start_time.total_seconds(),
                    "end_time": word_info.end_time.total_seconds(),
                }
            )
    return word_timestamps


def extract_sentence_pitch(y, sr):
    """문장 전체의 피치 데이터를 추출"""
    snd = parselmouth.Sound(y, sr)
    pitch = snd.to_pitch()
    frame_frequencies = pitch.selected_array["frequency"]
    valid_frequencies = frame_frequencies[
        frame_frequencies > 0
    ]  # 유효한 피치 데이터만 추출
    return (
        valid_frequencies if len(valid_frequencies) > 0 else np.array([0])
    )  # 빈 경우 0으로 처리


def extract_sentence_syllable_durations(y, sr):
    """문장 전체에서 음절 길이를 계산"""
    snd = parselmouth.Sound(y, sr)
    pitch = snd.to_pitch()
    frame_frequencies = pitch.selected_array["frequency"]
    valid_frames = frame_frequencies[frame_frequencies > 0]
    syllable_duration = (
        len(valid_frames) / pitch.ceiling if len(valid_frames) > 0 else 0
    )
    return syllable_duration


def calculate_cosine_similarity(vec1, vec2):
    """벡터 간 코사인 유사도 계산 (길이 패딩 포함)"""
    if len(vec1) == 0 or len(vec2) == 0:
        return 0.0
    max_len = max(len(vec1), len(vec2))
    vec1 = np.pad(vec1, (0, max_len - len(vec1)), mode="constant")
    vec2 = np.pad(vec2, (0, max_len - len(vec2)), mode="constant")
    return 1 - cosine(vec1, vec2)


def calculate_pitch_similarity(user_pitch, ref_pitch):
    """문장 전체의 피치 패턴 유사도 계산"""
    return calculate_cosine_similarity(user_pitch, ref_pitch)


def calculate_rhythm_similarity(user_timestamps, ref_timestamps):
    """문장 전체의 리듬 패턴 유사도 계산"""
    user_rhythm = [
        duration for word in user_timestamps for duration in word["syllable_durations"]
    ]
    ref_rhythm = [
        duration for word in ref_timestamps for duration in word["syllable_durations"]
    ]
    return calculate_cosine_similarity(user_rhythm, ref_rhythm)


def calculate_speed_ratio(user_timestamps, ref_timestamps):
    """발화 속도 차이를 계산 (초당 발화 단어 수)"""
    if len(user_timestamps) == 0 or len(ref_timestamps) == 0:
        return 0.0

    user_duration = user_timestamps[-1]["end_time"] - user_timestamps[0]["start_time"]
    ref_duration = ref_timestamps[-1]["end_time"] - ref_timestamps[0]["start_time"]

    user_speed = len(user_timestamps) / user_duration if user_duration > 0 else 0
    ref_speed = len(ref_timestamps) / ref_duration if ref_duration > 0 else 0

    return user_speed / ref_speed if ref_speed > 0 else 0


def analyze_audio(user_audio_path, ref_audio_path):
    """사용자와 기준 음성을 분석하여 결과 반환"""
    y_user, sr_user = preprocess_audio(user_audio_path)
    y_ref, sr_ref = preprocess_audio(ref_audio_path)

    user_timestamps = recognize_speech(y_user, sr_user)
    ref_timestamps = recognize_speech(y_ref, sr_ref)

    # 잘못 인식된 단어 추출
    user_words = [word["word"] for word in user_timestamps]
    ref_words = [word["word"] for word in ref_timestamps]
    mispronounced_words = list(set(user_words) - set(ref_words))
    excluded_words = mispronounced_words

    total_words = len(ref_words)
    mispronounced_ratio = (
        len(mispronounced_words) / total_words if total_words > 0 else 0
    )

    valid_user_timestamps = [
        word for word in user_timestamps if word["word"] not in excluded_words
    ]
    valid_ref_timestamps = [
        word for word in ref_timestamps if word["word"] not in excluded_words
    ]

    # 문장 전체 음절 길이 계산
    user_syllable_duration = extract_sentence_syllable_durations(y_user, sr_user)
    ref_syllable_duration = extract_sentence_syllable_durations(y_ref, sr_ref)
    rhythm_similarity = calculate_cosine_similarity(
        [user_syllable_duration], [ref_syllable_duration]
    )

    # 문장 전체 피치 패턴 계산
    user_pitch = extract_sentence_pitch(y_user, sr_user)
    ref_pitch = extract_sentence_pitch(y_ref, sr_ref)
    pitch_similarity = calculate_pitch_similarity(user_pitch, ref_pitch)

    # 발화 속도 및 기타 계산
    speed_ratio = calculate_speed_ratio(valid_user_timestamps, valid_ref_timestamps)
    pause_similarity = calculate_cosine_similarity(
        [word["end_time"] - word["start_time"] for word in valid_user_timestamps],
        [word["end_time"] - word["start_time"] for word in valid_ref_timestamps],
    )

    return {
        "Pitch Pattern": pitch_similarity,
        "Rhythm Pattern": rhythm_similarity,
        "Speed": speed_ratio,
        "Pause Pattern": pause_similarity,
        "Mispronounced Words": {
            "ratio": mispronounced_ratio,
            "list": mispronounced_words,
        },
    }


def compare_audio_folders(user_folder, ref_folder):
    user_files = sorted(os.listdir(user_folder), key=extract_number_from_filename)
    ref_files = sorted(os.listdir(ref_folder), key=extract_number_from_filename)

    results = {}
    for idx, (user_file, ref_file) in enumerate(zip(user_files, ref_files), start=1):
        user_audio_path = os.path.join(user_folder, user_file)
        ref_audio_path = os.path.join(ref_folder, ref_file)

        print(f"Comparing: {user_file} vs {ref_file}")
        result = analyze_audio(user_audio_path, ref_audio_path)
        results[f"comparison_{idx}"] = result

    return results


def main():
    user_folder = "./test_data/child_audio_100"
    ref_folder = "./test_data/tts_tortoise_audio_100"
    results = compare_audio_folders(user_folder, ref_folder)

    with open("results5.json", "w") as f:
        json.dump(results, f, indent=4)

    print(json.dumps(results, indent=4))


def extract_number_from_filename(filename):
    """파일 이름에서 숫자를 추출"""
    match = re.search(r"(\d+)", filename)
    return int(match.group(1)) if match else float("inf")

# %%
# 실행
if __name__ == "__main__":
    main()
# Out:
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04822489.wav vs sentence_1.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04822502.wav vs sentence_2.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04822529.wav vs sentence_3.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04822580.wav vs sentence_4.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04822594.wav vs sentence_5.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04822603.wav vs sentence_6.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04822635.wav vs sentence_7.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04822655.wav vs sentence_8.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04822681.wav vs sentence_9.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04822693.wav vs sentence_10.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04822705.wav vs sentence_11.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04822723.wav vs sentence_12.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04822746.wav vs sentence_13.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04822759.wav vs sentence_14.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04822782.wav vs sentence_15.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04822831.wav vs sentence_16.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04822849.wav vs sentence_17.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04822866.wav vs sentence_18.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04822926.wav vs sentence_19.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04822937.wav vs sentence_20.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04822956.wav vs sentence_21.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04822975.wav vs sentence_22.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04822996.wav vs sentence_23.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04823011.wav vs sentence_24.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04823045.wav vs sentence_25.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04823065.wav vs sentence_26.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04823086.wav vs sentence_27.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04823099.wav vs sentence_28.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04823163.wav vs sentence_29.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04823175.wav vs sentence_30.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04823185.wav vs sentence_31.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04823214.wav vs sentence_32.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04823263.wav vs sentence_33.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04823288.wav vs sentence_34.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04823314.wav vs sentence_35.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04823336.wav vs sentence_36.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04823352.wav vs sentence_37.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04823371.wav vs sentence_38.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04823396.wav vs sentence_39.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04823407.wav vs sentence_40.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04823418.wav vs sentence_41.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04823460.wav vs sentence_42.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04823480.wav vs sentence_43.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04823504.wav vs sentence_44.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04823534.wav vs sentence_45.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04823583.wav vs sentence_46.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04823596.wav vs sentence_47.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04823637.wav vs sentence_48.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04823656.wav vs sentence_49.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04823680.wav vs sentence_50.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04823698.wav vs sentence_51.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04823720.wav vs sentence_52.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04823754.wav vs sentence_53.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04823774.wav vs sentence_54.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04823797.wav vs sentence_55.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04823842.wav vs sentence_56.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04823869.wav vs sentence_57.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04823901.wav vs sentence_58.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04823926.wav vs sentence_59.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04823975.wav vs sentence_60.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04824002.wav vs sentence_61.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04824023.wav vs sentence_62.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04824058.wav vs sentence_63.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04824073.wav vs sentence_64.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04824093.wav vs sentence_65.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04824121.wav vs sentence_66.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04824136.wav vs sentence_67.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04824172.wav vs sentence_68.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04824207.wav vs sentence_69.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04824224.wav vs sentence_70.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04824237.wav vs sentence_71.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04824254.wav vs sentence_72.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04824285.wav vs sentence_73.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04824310.wav vs sentence_74.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04824322.wav vs sentence_75.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04824353.wav vs sentence_76.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04824376.wav vs sentence_77.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04824400.wav vs sentence_78.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04824452.wav vs sentence_79.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04824482.wav vs sentence_80.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04824522.wav vs sentence_81.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04824538.wav vs sentence_82.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04824553.wav vs sentence_83.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04843466.wav vs sentence_84.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04843496.wav vs sentence_85.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04843515.wav vs sentence_86.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04843530.wav vs sentence_87.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04843541.wav vs sentence_88.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04843556.wav vs sentence_89.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04843578.wav vs sentence_90.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04843592.wav vs sentence_91.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04843607.wav vs sentence_92.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04843627.wav vs sentence_93.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04843656.wav vs sentence_94.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04843682.wav vs sentence_95.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04843715.wav vs sentence_96.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04843726.wav vs sentence_97.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04843740.wav vs sentence_98.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04843754.wav vs sentence_99.wav
# Comparing: E0001A671-BFG33-L1N2D1-E-F5NX-04843766.wav vs sentence_100.wav
# {
#     "comparison_1": {
#         "Pitch Pattern": 0.8091233262896382,
#         "Rhythm Pattern": 1.0,
#         "Speed": 1.0,
#         "Pause Pattern": 0.9128811814866319,
#         "Mispronounced Words": {
#             "ratio": 0.0,
#             "list": []
#         }
#     },
#     "comparison_2": {
#         "Pitch Pattern": 0.8251689592377042,
#         "Rhythm Pattern": 1.0,
#         "Speed": 0.7894736842105263,
#         "Pause Pattern": 0.8730059212250615,
#         "Mispronounced Words": {
#             "ratio": 0.0,
#             "list": []
#         }
#     },
#     "comparison_3": {
#         "Pitch Pattern": 0.852419589559382,
#         "Rhythm Pattern": 1.0,
#         "Speed": 0.9142857142857143,
#         "Pause Pattern": 0.6049193494630825,
#         "Mispronounced Words": {
#             "ratio": 0.2857142857142857,
#             "list": [
#                 "lives",
#                 "can"
#             ]
#         }
#     },
#     "comparison_4": {
#         "Pitch Pattern": 0.9055051266458676,
#         "Rhythm Pattern": 1.0,
#         "Speed": 0.7333333333333332,
#         "Pause Pattern": 0.8516843901154347,
#         "Mispronounced Words": {
#             "ratio": 0.0,
#             "list": []
#         }
#     },
#     "comparison_5": {
#         "Pitch Pattern": 0.9748115845550247,
#         "Rhythm Pattern": 1.0,
#         "Speed": 5.333333333333329,
#         "Pause Pattern": 0.794101388315984,
#         "Mispronounced Words": {
#             "ratio": 0.3333333333333333,
#             "list": [
#                 "it's"
#             ]
#         }
#     },
#     "comparison_6": {
#         "Pitch Pattern": 0.9180019508268541,
#         "Rhythm Pattern": 1.0,
#         "Speed": 0.88,
#         "Pause Pattern": 0.6922261456116247,
#         "Mispronounced Words": {
#             "ratio": 0.0,
#             "list": []
#         }
#     },
#     "comparison_7": {
#         "Pitch Pattern": 0.8187494906783971,
#         "Rhythm Pattern": 1.0,
#         "Speed": 1.2258064516129035,
#         "Pause Pattern": 0.9116354187341819,
#         "Mispronounced Words": {
#             "ratio": 0.0,
#             "list": []
#         }
#     },
#     "comparison_8": {
#         "Pitch Pattern": 0.917625527255022,
#         "Rhythm Pattern": 1.0,
#         "Speed": 0.9705882352941176,
#         "Pause Pattern": 0.9142484131568984,
#         "Mispronounced Words": {
#             "ratio": 0.0,
#             "list": []
#         }
#     },
#     "comparison_9": {
#         "Pitch Pattern": 0.8727390592730573,
#         "Rhythm Pattern": 1.0,
#         "Speed": 1.7333333333333334,
#         "Pause Pattern": 0.6190103744689255,
#         "Mispronounced Words": {
#             "ratio": 0.2,
#             "list": [
#                 "your"
#             ]
#         }
#     },
#     "comparison_10": {
#         "Pitch Pattern": 0.7176430352453074,
#         "Rhythm Pattern": 1.0,
#         "Speed": 1.5000000000000002,
#         "Pause Pattern": 0.9335583806061623,
#         "Mispronounced Words": {
#             "ratio": 0.0,
#             "list": []
#         }
#     },
#     "comparison_11": {
#         "Pitch Pattern": 0.7644183435681102,
#         "Rhythm Pattern": 1.0,
#         "Speed": 1.3333333333333333,
#         "Pause Pattern": 0.8901845715516371,
#         "Mispronounced Words": {
#             "ratio": 0.0,
#             "list": []
#         }
#     },
#     "comparison_12": {
#         "Pitch Pattern": 0.6914384504062522,
#         "Rhythm Pattern": 1.0,
#         "Speed": 0.9523809523809523,
#         "Pause Pattern": 0.9038954841762055,
#         "Mispronounced Words": {
#             "ratio": 0.2,
#             "list": [
#                 "should"
#             ]
#         }
#     },
#     "comparison_13": {
#         "Pitch Pattern": 0.8151704932931153,
#         "Rhythm Pattern": 1.0,
#         "Speed": 1.026315789473684,
#         "Pause Pattern": 0.8830747023942337,
#         "Mispronounced Words": {
#             "ratio": 0.0,
#             "list": []
#         }
#     },
#     "comparison_14": {
#         "Pitch Pattern": 0.7752884999719626,
#         "Rhythm Pattern": 1.0,
#         "Speed": 1.4285714285714288,
#         "Pause Pattern": 0.9339747285492451,
#         "Mispronounced Words": {
#             "ratio": 0.0,
#             "list": []
#         }
#     },
#     "comparison_15": {
#         "Pitch Pattern": 0.7675958775275541,
#         "Rhythm Pattern": 1.0,
#         "Speed": 0.7096774193548386,
#         "Pause Pattern": 0.8573453731458801,
#         "Mispronounced Words": {
#             "ratio": 0.0,
#             "list": []
#         }
#     },
#     "comparison_16": {
#         "Pitch Pattern": 0.797962979385354,
#         "Rhythm Pattern": 1.0,
#         "Speed": 0.75,
#         "Pause Pattern": 0.873886059382867,
#         "Mispronounced Words": {
#             "ratio": 0.0,
#             "list": []
#         }
#     },
#     "comparison_17": {
#         "Pitch Pattern": 0.7944479485437219,
#         "Rhythm Pattern": 1.0,
#         "Speed": 0.9243697478991599,
#         "Pause Pattern": 0.6788225099390855,
#         "Mispronounced Words": {
#             "ratio": 0.2857142857142857,
#             "list": [
#                 "judger",
#                 "Island"
#             ]
#         }
#     },
#     "comparison_18": {
#         "Pitch Pattern": 0.8549882882461495,
#         "Rhythm Pattern": 1.0,
#         "Speed": 0.7894736842105262,
#         "Pause Pattern": 0.9280304167756537,
#         "Mispronounced Words": {
#             "ratio": 0.0,
#             "list": []
#         }
#     },
#     "comparison_19": {
#         "Pitch Pattern": 0.804867685710023,
#         "Rhythm Pattern": 1.0,
#         "Speed": 0.505050505050505,
#         "Pause Pattern": 0.4552394193085805,
#         "Mispronounced Words": {
#             "ratio": 0.4444444444444444,
#             "list": [
#                 "need",
#                 "p",
#                 "snakes",
#                 "a"
#             ]
#         }
#     },
#     "comparison_20": {
#         "Pitch Pattern": 0.8567941306207043,
#         "Rhythm Pattern": 1.0,
#         "Speed": 0.625,
#         "Pause Pattern": 0.9867408718228069,
#         "Mispronounced Words": {
#             "ratio": 0.0,
#             "list": []
#         }
#     },
#     "comparison_21": {
#         "Pitch Pattern": 0.8337405056011991,
#         "Rhythm Pattern": 1.0,
#         "Speed": 0.6985294117647058,
#         "Pause Pattern": 0.7734924681537618,
#         "Mispronounced Words": {
#             "ratio": 0.25,
#             "list": [
#                 "order",
#                 "sister"
#             ]
#         }
#     },
#     "comparison_22": {
#         "Pitch Pattern": 0.8920918611365662,
#         "Rhythm Pattern": 0.9999999999999998,
#         "Speed": 0.7222222222222222,
#         "Pause Pattern": 0.9970374587164187,
#         "Mispronounced Words": {
#             "ratio": 0.0,
#             "list": []
#         }
#     },
#     "comparison_23": {
#         "Pitch Pattern": 0.813734752030665,
#         "Rhythm Pattern": 1.0,
#         "Speed": 1.103448275862069,
#         "Pause Pattern": 0.9097893192901222,
#         "Mispronounced Words": {
#             "ratio": 0.0,
#             "list": []
#         }
#     },
#     "comparison_24": {
#         "Pitch Pattern": 0.8851435818855218,
#         "Rhythm Pattern": 1.0,
#         "Speed": 0.8666666666666668,
#         "Pause Pattern": 0.9035841064985974,
#         "Mispronounced Words": {
#             "ratio": 0.0,
#             "list": []
#         }
#     },
#     "comparison_25": {
#         "Pitch Pattern": 0.9572103085393354,
#         "Rhythm Pattern": 1.0,
#         "Speed": 0.6481481481481483,
#         "Pause Pattern": 0.8625812089227879,
#         "Mispronounced Words": {
#             "ratio": 0.16666666666666666,
#             "list": [
#                 "game"
#             ]
#         }
#     },
#     "comparison_26": {
#         "Pitch Pattern": 0.8633929521566748,
#         "Rhythm Pattern": 1.0,
#         "Speed": 0.6388888888888887,
#         "Pause Pattern": 0.6999409255041813,
#         "Mispronounced Words": {
#             "ratio": 0.0,
#             "list": []
#         }
#     },
#     "comparison_27": {
#         "Pitch Pattern": 0.8250485989178392,
#         "Rhythm Pattern": 1.0,
#         "Speed": 0.6521739130434783,
#         "Pause Pattern": 0.8835543623799025,
#         "Mispronounced Words": {
#             "ratio": 0.0,
#             "list": []
#         }
#     },
#     "comparison_28": {
#         "Pitch Pattern": 0.8110800495224186,
#         "Rhythm Pattern": 1.0,
#         "Speed": 1.1250000000000002,
#         "Pause Pattern": 0.37463432463267754,
#         "Mispronounced Words": {
#             "ratio": 1.0,
#             "list": [
#                 "I'm",
#                 "called",
#                 "word",
#                 "the"
#             ]
#         }
#     },
#     "comparison_29": {
#         "Pitch Pattern": 0.82373021747914,
#         "Rhythm Pattern": 1.0,
#         "Speed": 1.0526315789473684,
#         "Pause Pattern": 0.6392930878508799,
#         "Mispronounced Words": {
#             "ratio": 0.3333333333333333,
#             "list": [
#                 "she",
#                 "said"
#             ]
#         }
#     },
#     "comparison_30": {
#         "Pitch Pattern": 0.9595482958436705,
#         "Rhythm Pattern": 1.0,
#         "Speed": 0.8620689655172414,
#         "Pause Pattern": 0.805993310283287,
#         "Mispronounced Words": {
#             "ratio": 0.0,
#             "list": []
#         }
#     },
#     "comparison_31": {
#         "Pitch Pattern": 0.9746737722946536,
#         "Rhythm Pattern": 1.0,
#         "Speed": 0.8709677419354839,
#         "Pause Pattern": 0.8273879319702251,
#         "Mispronounced Words": {
#             "ratio": 0.0,
#             "list": []
#         }
#     },
#     "comparison_32": {
#         "Pitch Pattern": 0.8827463054263307,
#         "Rhythm Pattern": 1.0,
#         "Speed": 0.6666666666666667,
#         "Pause Pattern": 0.7278099754270118,
#         "Mispronounced Words": {
#             "ratio": 0.1111111111111111,
#             "list": [
#                 "go"
#             ]
#         }
#     },
#     "comparison_33": {
#         "Pitch Pattern": 0.8971816973248682,
#         "Rhythm Pattern": 0.9999999999999998,
#         "Speed": 0.986842105263158,
#         "Pause Pattern": 0.7660323462854263,
#         "Mispronounced Words": {
#             "ratio": 0.375,
#             "list": [
#                 "Earth",
#                 "Academy",
#                 "on"
#             ]
#         }
#     },
#     "comparison_34": {
#         "Pitch Pattern": 0.9459546971005686,
#         "Rhythm Pattern": 1.0,
#         "Speed": 0.6060606060606061,
#         "Pause Pattern": 0.7261728482333455,
#         "Mispronounced Words": {
#             "ratio": 0.25,
#             "list": [
#                 "faster",
#                 "s"
#             ]
#         }
#     },
#     "comparison_35": {
#         "Pitch Pattern": 0.7710941902285321,
#         "Rhythm Pattern": 1.0,
#         "Speed": 0.3783783783783784,
#         "Pause Pattern": 0.45709816726414143,
#         "Mispronounced Words": {
#             "ratio": 0.3333333333333333,
#             "list": [
#                 "on",
#                 "picked"
#             ]
#         }
#     },
#     "comparison_36": {
#         "Pitch Pattern": 0.8824523305176386,
#         "Rhythm Pattern": 1.0,
#         "Speed": 0.4824561403508771,
#         "Pause Pattern": 0.5328751623948317,
#         "Mispronounced Words": {
#             "ratio": 0.3333333333333333,
#             "list": [
#                 "plane",
#                 "trade",
#                 "also"
#             ]
#         }
#     },
#     "comparison_37": {
#         "Pitch Pattern": 0.9271993562219467,
#         "Rhythm Pattern": 1.0,
#         "Speed": 1.169230769230769,
#         "Pause Pattern": 0.7092081432669751,
#         "Mispronounced Words": {
#             "ratio": 0.2,
#             "list": [
#                 "milks",
#                 "drink"
#             ]
#         }
#     },
#     "comparison_38": {
#         "Pitch Pattern": 0.7606093242619065,
#         "Rhythm Pattern": 1.0,
#         "Speed": 1.0357142857142854,
#         "Pause Pattern": 0.3833259389999639,
#         "Mispronounced Words": {
#             "ratio": 1.5,
#             "list": [
#                 "the",
#                 "5050",
#                 "Finance",
#                 "of",
#                 "a",
#                 "school"
#             ]
#         }
#     },
#     "comparison_39": {
#         "Pitch Pattern": 0.783133870027815,
#         "Rhythm Pattern": 1.0,
#         "Speed": 0.7205882352941178,
#         "Pause Pattern": 0.8097230026349558,
#         "Mispronounced Words": {
#             "ratio": 0.125,
#             "list": [
#                 "Bloom"
#             ]
#         }
#     },
#     "comparison_40": {
#         "Pitch Pattern": 0.9094369576652545,
#         "Rhythm Pattern": 1.0,
#         "Speed": 0.7894736842105263,
#         "Pause Pattern": 0.9474129498752366,
#         "Mispronounced Words": {
#             "ratio": 0.0,
#             "list": []
#         }
#     },
#     "comparison_41": {
#         "Pitch Pattern": 0.7426753202817092,
#         "Rhythm Pattern": 1.0,
#         "Speed": 1.0000000000000002,
#         "Pause Pattern": 0.9257856948189074,
#         "Mispronounced Words": {
#             "ratio": 0.0,
#             "list": []
#         }
#     },
#     "comparison_42": {
#         "Pitch Pattern": 0.8836695860527257,
#         "Rhythm Pattern": 1.0,
#         "Speed": 0.6250000000000001,
#         "Pause Pattern": 0.4310629761865403,
#         "Mispronounced Words": {
#             "ratio": 0.25,
#             "list": [
#                 "have"
#             ]
#         }
#     },
#     "comparison_43": {
#         "Pitch Pattern": 0.9405506858201442,
#         "Rhythm Pattern": 1.0,
#         "Speed": 0.6956521739130436,
#         "Pause Pattern": 0.9301133046536163,
#         "Mispronounced Words": {
#             "ratio": 0.2,
#             "list": [
#                 "will"
#             ]
#         }
#     },
#     "comparison_44": {
#         "Pitch Pattern": 0.898978032467922,
#         "Rhythm Pattern": 1.0,
#         "Speed": 1.0370370370370372,
#         "Pause Pattern": 0.5388159060803244,
#         "Mispronounced Words": {
#             "ratio": 0.3333333333333333,
#             "list": [
#                 "will",
#                 "choice",
#                 "I"
#             ]
#         }
#     },
#     "comparison_45": {
#         "Pitch Pattern": 0.7177091957601944,
#         "Rhythm Pattern": 1.0,
#         "Speed": 0.9636752136752136,
#         "Pause Pattern": 0.7041627586473942,
#         "Mispronounced Words": {
#             "ratio": 0.08333333333333333,
#             "list": [
#                 "kiss"
#             ]
#         }
#     },
#     "comparison_46": {
#         "Pitch Pattern": 0.979478588819107,
#         "Rhythm Pattern": 1.0,
#         "Speed": 0.8275862068965517,
#         "Pause Pattern": 0.9443790141299616,
#         "Mispronounced Words": {
#             "ratio": 0.0,
#             "list": []
#         }
#     },
#     "comparison_47": {
#         "Pitch Pattern": 0.8621382256663196,
#         "Rhythm Pattern": 1.0,
#         "Speed": 0.65,
#         "Pause Pattern": 0.9297455982527455,
#         "Mispronounced Words": {
#             "ratio": 0.0,
#             "list": []
#         }
#     },
#     "comparison_48": {
#         "Pitch Pattern": 0.8372583776054905,
#         "Rhythm Pattern": 1.0,
#         "Speed": 0.8235294117647058,
#         "Pause Pattern": 0.9889366221864397,
#         "Mispronounced Words": {
#             "ratio": 0.0,
#             "list": []
#         }
#     },
#     "comparison_49": {
#         "Pitch Pattern": 0.8497005581800114,
#         "Rhythm Pattern": 0.9999999999999998,
#         "Speed": 0.6666666666666665,
#         "Pause Pattern": 0.9687932934259312,
#         "Mispronounced Words": {
#             "ratio": 0.0,
#             "list": []
#         }
#     },
#     "comparison_50": {
#         "Pitch Pattern": 0.844966761463762,
#         "Rhythm Pattern": 1.0,
#         "Speed": 1.15,
#         "Pause Pattern": 0.8396846319449335,
#         "Mispronounced Words": {
#             "ratio": 0.0,
#             "list": []
#         }
#     },
#     "comparison_51": {
#         "Pitch Pattern": 0.6942650831132676,
#         "Rhythm Pattern": 1.0,
#         "Speed": 2.3999999999999977,
#         "Pause Pattern": 0.5262348115842175,
#         "Mispronounced Words": {
#             "ratio": 0.4,
#             "list": [
#                 "books",
#                 "enjoy"
#             ]
#         }
#     },
#     "comparison_52": {
#         "Pitch Pattern": 0.9021120142908327,
#         "Rhythm Pattern": 1.0,
#         "Speed": 0.6477272727272727,
#         "Pause Pattern": 0.795411678668406,
#         "Mispronounced Words": {
#             "ratio": 0.25,
#             "list": [
#                 "what",
#                 "Rudin"
#             ]
#         }
#     },
#     "comparison_53": {
#         "Pitch Pattern": 0.9321071732350927,
#         "Rhythm Pattern": 1.0,
#         "Speed": 0.7619047619047619,
#         "Pause Pattern": 0.9181561700975341,
#         "Mispronounced Words": {
#             "ratio": 0.0,
#             "list": []
#         }
#     },
#     "comparison_54": {
#         "Pitch Pattern": 0.9318555183188164,
#         "Rhythm Pattern": 1.0,
#         "Speed": 0.6689189189189189,
#         "Pause Pattern": 0.8583901900818827,
#         "Mispronounced Words": {
#             "ratio": 0.25,
#             "list": [
#                 "write",
#                 "touched"
#             ]
#         }
#     },
#     "comparison_55": {
#         "Pitch Pattern": 0.9170811888009175,
#         "Rhythm Pattern": 1.0,
#         "Speed": 1.0,
#         "Pause Pattern": 0.8627901599618504,
#         "Mispronounced Words": {
#             "ratio": 0.0,
#             "list": []
#         }
#     },
#     "comparison_56": {
#         "Pitch Pattern": 0.9508270369433901,
#         "Rhythm Pattern": 1.0,
#         "Speed": 0.6521739130434784,
#         "Pause Pattern": 0.9641958647341593,
#         "Mispronounced Words": {
#             "ratio": 0.0,
#             "list": []
#         }
#     },
#     "comparison_57": {
#         "Pitch Pattern": 0.8584631910841913,
#         "Rhythm Pattern": 1.0,
#         "Speed": 1.2666666666666666,
#         "Pause Pattern": 0.955325429033761,
#         "Mispronounced Words": {
#             "ratio": 0.0,
#             "list": []
#         }
#     },
#     "comparison_58": {
#         "Pitch Pattern": 0.8547716523329374,
#         "Rhythm Pattern": 1.0,
#         "Speed": 1.1428571428571428,
#         "Pause Pattern": 0.8454027929649517,
#         "Mispronounced Words": {
#             "ratio": 0.42857142857142855,
#             "list": [
#                 "too",
#                 "Anker",
#                 "running"
#             ]
#         }
#     },
#     "comparison_59": {
#         "Pitch Pattern": 0.959135750745395,
#         "Rhythm Pattern": 0.9999999999999999,
#         "Speed": 0.6666666666666666,
#         "Pause Pattern": 0.7859565433852952,
#         "Mispronounced Words": {
#             "ratio": 0.2,
#             "list": [
#                 "grandmother",
#                 "soon's"
#             ]
#         }
#     },
#     "comparison_60": {
#         "Pitch Pattern": 0.8460686286991591,
#         "Rhythm Pattern": 1.0,
#         "Speed": 0.8181818181818181,
#         "Pause Pattern": 0.7377371622246685,
#         "Mispronounced Words": {
#             "ratio": 0.0,
#             "list": []
#         }
#     },
#     "comparison_61": {
#         "Pitch Pattern": 0.8869311571415146,
#         "Rhythm Pattern": 1.0,
#         "Speed": 0.5641025641025641,
#         "Pause Pattern": 0.6499288335384259,
#         "Mispronounced Words": {
#             "ratio": 0.3333333333333333,
#             "list": [
#                 "thing",
#                 "the"
#             ]
#         }
#     },
#     "comparison_62": {
#         "Pitch Pattern": 0.752267852582044,
#         "Rhythm Pattern": 1.0,
#         "Speed": 0.7242798353909465,
#         "Pause Pattern": 0.5461301788712284,
#         "Mispronounced Words": {
#             "ratio": 0.1111111111111111,
#             "list": [
#                 "lights"
#             ]
#         }
#     },
#     "comparison_63": {
#         "Pitch Pattern": 0.9330866967502284,
#         "Rhythm Pattern": 0.9999999999999999,
#         "Speed": 1.027027027027027,
#         "Pause Pattern": 0.8831786506622018,
#         "Mispronounced Words": {
#             "ratio": 0.1111111111111111,
#             "list": [
#                 "brother"
#             ]
#         }
#     },
#     "comparison_64": {
#         "Pitch Pattern": 0.9344839617916928,
#         "Rhythm Pattern": 0.9999999999999999,
#         "Speed": 0.9124423963133639,
#         "Pause Pattern": 0.696102056068575,
#         "Mispronounced Words": {
#             "ratio": 0.14285714285714285,
#             "list": [
#                 "brings"
#             ]
#         }
#     },
#     "comparison_65": {
#         "Pitch Pattern": 0.7921873944421253,
#         "Rhythm Pattern": 1.0,
#         "Speed": 1.0789473684210524,
#         "Pause Pattern": 0.889962108828795,
#         "Mispronounced Words": {
#             "ratio": 0.0,
#             "list": []
#         }
#     },
#     "comparison_66": {
#         "Pitch Pattern": 0.951688332732076,
#         "Rhythm Pattern": 1.0,
#         "Speed": 0.7619047619047621,
#         "Pause Pattern": 0.5373622334465277,
#         "Mispronounced Words": {
#             "ratio": 0.5,
#             "list": [
#                 "run",
#                 "lock",
#                 "the"
#             ]
#         }
#     },
#     "comparison_67": {
#         "Pitch Pattern": 0.9928257563748486,
#         "Rhythm Pattern": 0.9999999999999998,
#         "Speed": 1.0909090909090904,
#         "Pause Pattern": 0.8476290894688452,
#         "Mispronounced Words": {
#             "ratio": 0.2,
#             "list": [
#                 "I'd"
#             ]
#         }
#     },
#     "comparison_68": {
#         "Pitch Pattern": 0.9008617896033685,
#         "Rhythm Pattern": 1.0,
#         "Speed": 0.8839285714285714,
#         "Pause Pattern": 0.6599120175960899,
#         "Mispronounced Words": {
#             "ratio": 0.25,
#             "list": [
#                 "was",
#                 "hoping"
#             ]
#         }
#     },
#     "comparison_69": {
#         "Pitch Pattern": 0.9094332661354854,
#         "Rhythm Pattern": 1.0,
#         "Speed": 0.8108108108108107,
#         "Pause Pattern": 0.7097543145938038,
#         "Mispronounced Words": {
#             "ratio": 0.09090909090909091,
#             "list": [
#                 "by"
#             ]
#         }
#     },
#     "comparison_70": {
#         "Pitch Pattern": 0.9104113778733921,
#         "Rhythm Pattern": 1.0,
#         "Speed": 1.2105263157894735,
#         "Pause Pattern": 0.6908400112284045,
#         "Mispronounced Words": {
#             "ratio": 0.0,
#             "list": []
#         }
#     },
#     "comparison_71": {
#         "Pitch Pattern": 0.7937791370465455,
#         "Rhythm Pattern": 1.0,
#         "Speed": 0.689655172413793,
#         "Pause Pattern": 0.7554973565193744,
#         "Mispronounced Words": {
#             "ratio": 0.0,
#             "list": []
#         }
#     },
#     "comparison_72": {
#         "Pitch Pattern": 0.7795770366746533,
#         "Rhythm Pattern": 1.0,
#         "Speed": 0.5581395348837209,
#         "Pause Pattern": 0.8447361343583257,
#         "Mispronounced Words": {
#             "ratio": 0.2222222222222222,
#             "list": [
#                 "first",
#                 "academic"
#             ]
#         }
#     },
#     "comparison_73": {
#         "Pitch Pattern": 0.8447177694635655,
#         "Rhythm Pattern": 1.0,
#         "Speed": 1.2500000000000002,
#         "Pause Pattern": 0.7347349732399965,
#         "Mispronounced Words": {
#             "ratio": 0.0,
#             "list": []
#         }
#     },
#     "comparison_74": {
#         "Pitch Pattern": 0.939331724016424,
#         "Rhythm Pattern": 1.0,
#         "Speed": 0.617283950617284,
#         "Pause Pattern": 0.5749430762167037,
#         "Mispronounced Words": {
#             "ratio": 0.16666666666666666,
#             "list": [
#                 "friends"
#             ]
#         }
#     },
#     "comparison_75": {
#         "Pitch Pattern": 0.9324058413613697,
#         "Rhythm Pattern": 1.0,
#         "Speed": 0.9158249158249158,
#         "Pause Pattern": 0.8408298206218302,
#         "Mispronounced Words": {
#             "ratio": 0.1111111111111111,
#             "list": [
#                 "can"
#             ]
#         }
#     },
#     "comparison_76": {
#         "Pitch Pattern": 0.9261307233926446,
#         "Rhythm Pattern": 0.9999999999999998,
#         "Speed": 0.4705882352941176,
#         "Pause Pattern": 0.9283174326780431,
#         "Mispronounced Words": {
#             "ratio": 0.0,
#             "list": []
#         }
#     },
#     "comparison_77": {
#         "Pitch Pattern": 0.9607710146798853,
#         "Rhythm Pattern": 1.0,
#         "Speed": 0.7857142857142858,
#         "Pause Pattern": 0.7090073254627264,
#         "Mispronounced Words": {
#             "ratio": 0.0,
#             "list": []
#         }
#     },
#     "comparison_78": {
#         "Pitch Pattern": 0.9047706202973634,
#         "Rhythm Pattern": 1.0,
#         "Speed": 1.1428571428571432,
#         "Pause Pattern": 0.5962847939999439,
#         "Mispronounced Words": {
#             "ratio": 0.5,
#             "list": [
#                 "toy",
#                 "Earth",
#                 "from"
#             ]
#         }
#     },
#     "comparison_79": {
#         "Pitch Pattern": 0.8202560222891077,
#         "Rhythm Pattern": 1.0,
#         "Speed": 0.7843137254901961,
#         "Pause Pattern": 0.7049123409692188,
#         "Mispronounced Words": {
#             "ratio": 0.3333333333333333,
#             "list": [
#                 "will",
#                 "I"
#             ]
#         }
#     },
#     "comparison_80": {
#         "Pitch Pattern": 0.6008716484760289,
#         "Rhythm Pattern": 1.0,
#         "Speed": 1.176470588235294,
#         "Pause Pattern": 0.6544605290396027,
#         "Mispronounced Words": {
#             "ratio": 0.0,
#             "list": []
#         }
#     },
#     "comparison_81": {
#         "Pitch Pattern": 0.9098124000889993,
#         "Rhythm Pattern": 1.0,
#         "Speed": 0.9285714285714285,
#         "Pause Pattern": 0.5800828879602641,
#         "Mispronounced Words": {
#             "ratio": 0.3333333333333333,
#             "list": [
#                 "sing",
#                 "B"
#             ]
#         }
#     },
#     "comparison_82": {
#         "Pitch Pattern": 0.9687280340161836,
#         "Rhythm Pattern": 1.0,
#         "Speed": 0.5909090909090909,
#         "Pause Pattern": 0.49045967047296624,
#         "Mispronounced Words": {
#             "ratio": 0.5,
#             "list": [
#                 "love",
#                 "what"
#             ]
#         }
#     },
#     "comparison_83": {
#         "Pitch Pattern": 0.6773760824874995,
#         "Rhythm Pattern": 1.0,
#         "Speed": 1.730769230769231,
#         "Pause Pattern": 0.7531974146440829,
#         "Mispronounced Words": {
#             "ratio": 0.25,
#             "list": [
#                 "move"
#             ]
#         }
#     },
#     "comparison_84": {
#         "Pitch Pattern": 0.8718882112282382,
#         "Rhythm Pattern": 1.0,
#         "Speed": 1.2307692307692304,
#         "Pause Pattern": 0.8138398802335735,
#         "Mispronounced Words": {
#             "ratio": 0.4,
#             "list": [
#                 "father",
#                 "May"
#             ]
#         }
#     },
#     "comparison_85": {
#         "Pitch Pattern": 0.9089852962743703,
#         "Rhythm Pattern": 1.0,
#         "Speed": 0.6250000000000001,
#         "Pause Pattern": 0.492827110374054,
#         "Mispronounced Words": {
#             "ratio": 0.375,
#             "list": [
#                 "want",
#                 "on",
#                 "form"
#             ]
#         }
#     },
#     "comparison_86": {
#         "Pitch Pattern": 0.929742096061805,
#         "Rhythm Pattern": 0.9999999999999998,
#         "Speed": 0.6842105263157895,
#         "Pause Pattern": 0.9724453116434619,
#         "Mispronounced Words": {
#             "ratio": 0.0,
#             "list": []
#         }
#     },
#     "comparison_87": {
#         "Pitch Pattern": 0.7453390235158145,
#         "Rhythm Pattern": 1.0,
#         "Speed": 0.8076923076923079,
#         "Pause Pattern": 0.7823042886243178,
#         "Mispronounced Words": {
#             "ratio": 0.5,
#             "list": [
#                 "knickers",
#                 "shoes"
#             ]
#         }
#     },
#     "comparison_88": {
#         "Pitch Pattern": 0.6768880421655374,
#         "Rhythm Pattern": 0.9999999999999999,
#         "Speed": 0.4848484848484848,
#         "Pause Pattern": 0.7219948723811553,
#         "Mispronounced Words": {
#             "ratio": 0.0,
#             "list": []
#         }
#     },
#     "comparison_89": {
#         "Pitch Pattern": 0.9060986041985328,
#         "Rhythm Pattern": 1.0,
#         "Speed": 0.90234375,
#         "Pause Pattern": 0.8079617551606002,
#         "Mispronounced Words": {
#             "ratio": 0.125,
#             "list": [
#                 "grace"
#             ]
#         }
#     },
#     "comparison_90": {
#         "Pitch Pattern": 0.9640847511347058,
#         "Rhythm Pattern": 1.0,
#         "Speed": 1.1868131868131866,
#         "Pause Pattern": 0.2931173966505197,
#         "Mispronounced Words": {
#             "ratio": 0.42857142857142855,
#             "list": [
#                 "there",
#                 "they",
#                 "is"
#             ]
#         }
#     },
#     "comparison_91": {
#         "Pitch Pattern": 0.823033079192129,
#         "Rhythm Pattern": 1.0,
#         "Speed": 1.0,
#         "Pause Pattern": 0.9311039008066343,
#         "Mispronounced Words": {
#             "ratio": 0.0,
#             "list": []
#         }
#     },
#     "comparison_92": {
#         "Pitch Pattern": 0.9066325978545358,
#         "Rhythm Pattern": 1.0,
#         "Speed": 1.0,
#         "Pause Pattern": 0.7666558411081679,
#         "Mispronounced Words": {
#             "ratio": 0.0,
#             "list": []
#         }
#     },
#     "comparison_93": {
#         "Pitch Pattern": 0.9378480265131023,
#         "Rhythm Pattern": 1.0,
#         "Speed": 1.1333333333333335,
#         "Pause Pattern": 0.7300801858692382,
#         "Mispronounced Words": {
#             "ratio": 0.0,
#             "list": []
#         }
#     },
#     "comparison_94": {
#         "Pitch Pattern": 0.7975950769072283,
#         "Rhythm Pattern": 1.0,
#         "Speed": 0.9272727272727272,
#         "Pause Pattern": 0.7649256939429964,
#         "Mispronounced Words": {
#             "ratio": 0.2,
#             "list": [
#                 "sucked",
#                 "the"
#             ]
#         }
#     },
#     "comparison_95": {
#         "Pitch Pattern": 0.7757954924196998,
#         "Rhythm Pattern": 1.0,
#         "Speed": 0.9750000000000001,
#         "Pause Pattern": 0.8027826170972991,
#         "Mispronounced Words": {
#             "ratio": 0.09090909090909091,
#             "list": [
#                 "will"
#             ]
#         }
#     },
#     "comparison_96": {
#         "Pitch Pattern": 0.8675995851737762,
#         "Rhythm Pattern": 1.0,
#         "Speed": 1.0666666666666667,
#         "Pause Pattern": 0.9363247258351782,
#         "Mispronounced Words": {
#             "ratio": 0.0,
#             "list": []
#         }
#     },
#     "comparison_97": {
#         "Pitch Pattern": 0.9735123009825749,
#         "Rhythm Pattern": 0.9999999999999998,
#         "Speed": 0.7500000000000001,
#         "Pause Pattern": 0.8706439794037532,
#         "Mispronounced Words": {
#             "ratio": 0.0,
#             "list": []
#         }
#     },
#     "comparison_98": {
#         "Pitch Pattern": 0.8179755002408708,
#         "Rhythm Pattern": 1.0,
#         "Speed": 0.9075630252100841,
#         "Pause Pattern": 0.5385558215091134,
#         "Mispronounced Words": {
#             "ratio": 0.14285714285714285,
#             "list": [
#                 "has"
#             ]
#         }
#     },
#     "comparison_99": {
#         "Pitch Pattern": 0.5754918577891092,
#         "Rhythm Pattern": 1.0,
#         "Speed": 1.85,
#         "Pause Pattern": 0.9200578266714288,
#         "Mispronounced Words": {
#             "ratio": 0.0,
#             "list": []
#         }
#     },
#     "comparison_100": {
#         "Pitch Pattern": 0.9008728467808347,
#         "Rhythm Pattern": 1.0,
#         "Speed": 0.8666666666666668,
#         "Pause Pattern": 0.589431920891186,
#         "Mispronounced Words": {
#             "ratio": 0.2,
#             "list": [
#                 "puppy"
#             ]
#         }
#     }
# }

# %%
import json
import numpy as np
import pandas as pd


def calculate_statistics(json_file_path):
    # JSON 파일 불러오기
    with open(json_file_path, "r") as file:
        data = json.load(file)

    # 비교 항목 데이터를 추출하여 DataFrame 생성
    comparisons = []
    for key, values in data.items():
        comparisons.append(
            {
                "Pitch Pattern": values["Pitch Pattern"],
                "Rhythm Pattern": values["Rhythm Pattern"],
                "Speed": values["Speed"],
                "Pause Pattern": values["Pause Pattern"],
                "Mispronounced Words Ratio": values["Mispronounced Words"]["ratio"],
            }
        )

    df = pd.DataFrame(comparisons)

    # 통계량 계산
    stats = (
        df.describe(percentiles=[0.25, 0.5, 0.75])
        .loc[["min", "25%", "50%", "75%", "max", "mean"]]
        .T
    )
    stats.columns = ["Min", "Q1", "Median", "Q3", "Max", "Mean"]

    # 결과 출력
    print(stats)


# 실행
json_file_path = "pronunciation_evaluation_result.json"
calculate_statistics(json_file_path)
# Out:
#                                 Min        Q1    Median        Q3       Max  \
# Pitch Pattern              0.575492  0.808059  0.869744  0.920034  0.992826
# Rhythm Pattern             1.000000  1.000000  1.000000  1.000000  1.000000
# Speed                      0.378378  0.694153  0.875484  1.056140  5.333333
# Pause Pattern              0.293117  0.687836  0.799097  0.903662  0.997037
# Mispronounced Words Ratio  0.000000  0.000000  0.090909  0.250000  1.500000
#
#                                Mean
# Pitch Pattern              0.857399
# Rhythm Pattern             1.000000
# Speed                      0.957689
# Pause Pattern              0.766998
# Mispronounced Words Ratio  0.157405
